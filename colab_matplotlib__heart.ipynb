# %% [markdown]
# <a href="https://colab.research.google.com/github/taeo09/matplotlib_-/blob/main/colab_matplotlib__heart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 2 * np.pi, 1000)
x = 16 * np.sin(t)**3
y = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)

plt.plot(x, y, color='red', linewidth=2)
plt.fill_between(x, y, color='red', alpha=0.3)
plt.title('Heart Shape with Matplotlib')
plt.axis('equal')  # x, y 축 비율 같게
plt.axis('off')    # 축 숨기기
plt.show()

# %% [markdown]
# 1 matplotlib 맛보기
